# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\USER'

# %%
import pandas as pd
import sys
a='automobile.csv'
df=pd.read_csv(a)
df.head()
x=df[['fuel-type']]
x.head()
df.loc[0:2]
df.ix[5,7]
df.iloc[0:10,0:10]
y=df[["make","body-style","fuel-type"]]
y
df['make'].unique()
df['symboling']>1
df1=df[df['symboling']>2]
df1.to_csv('new_automobile.csv')
df1
# Out:
# C:\Users\USER\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   # Remove the CWD from sys.path while we load stuff.
#      Unnamed: 0  symboling normalized-losses           make fuel-type  \
# 0             0          3                 ?    alfa-romero       gas
# 1             1          3                 ?    alfa-romero       gas
# 29           29          3               145          dodge       gas
# 55           55          3               150          mazda       gas
# 56           56          3               150          mazda       gas
# 57           57          3               150          mazda       gas
# 58           58          3               150          mazda       gas
# ...

# %%
b='top_selling_albums.xlsx'
df=pd.read_excel(b)
df.head()
#df.ix[2,1]
#df[['Genre']]
df1=df[df['Rating']>8.0]
df1
df.loc[1:5]
df.iloc[1:5,1:6]
z=df[['Album','Released','Genre']]
z
df['Released'].unique()
# Out:
# array([1982, 1980, 1973, 1992, 1977, 1976], dtype=int64)
